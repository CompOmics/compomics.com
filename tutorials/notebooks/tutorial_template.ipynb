# %% [markdown]
# # <Tool Name>: <Short Task Description>
#
# **Tool version:** <e.g. 1.2.0>
# **Estimated time:** <e.g. 15 min>
# **Level:** <beginner / intermediate / advanced>
# **Last tested:** <YYYY-MM-DD, against tool version above>
#
# ## Abstract
#
# One or two sentences: what this tutorial covers and what the reader will produce by the end (e.g. a filtered PSM table, a retention time prediction plot).

# %% [markdown]
# ## Learning objectives
#
# By the end of this tutorial, you will be able to:
#
# - Objective 1
# - Objective 2
# - Objective 3
#
# ## Prerequisites
#
# - Familiarity with: <e.g. basic Python, mzML format>
# - Required background tutorials (if any): <link>
#
# ## Input data
#
# - Description of the example dataset used (source, size, format).
# - Link to download / Zenodo DOI if applicable.

# %% [markdown]
# ## 1. Setup

# %%
# Pin versions in requirements.txt / environment.yml alongside this notebook,
# not just here — this import block is for readability, not reproducibility.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# import <compomics_tool>

# %matplotlib inline

# %%
# Download / load example data
# Prefer a small bundled or Zenodo-hosted dataset so the notebook runs standalone

data_path = "path/to/example_data"
# df = pd.read_csv(data_path)

# %% [markdown]
# ## 2. <First processing step>
#
# Short explanation of what this step does and why it matters, before showing the code.

# %%
# One action per cell. Keep code cells short and focused.

# result = tool.process(df)

# %% [markdown]
# ## 3. <Second processing step>
#
# Explanation of parameters worth tuning, and what a reasonable default looks like.

# %%
# result_filtered = tool.filter(result, threshold=0.01)

# %% [markdown]
# ## 4. Visualize the results
#
# Every tutorial should end its processing section with a visualization of the data or of the processing steps applied (e.g. before/after distributions, a workflow diagram, score distributions).

# %%
fig, ax = plt.subplots(figsize=(6, 4))

# ax.hist(result_filtered["score"], bins=50)
# ax.set_xlabel("Score")
# ax.set_ylabel("Count")
# ax.set_title("<Descriptive title>")

plt.show()

# %% [markdown]
# ## Key points
#
# - Key point 1
# - Key point 2
# - Key point 3
#
# ## Next steps
#
# - Link to a follow-up tutorial, or to the tool's full documentation / API reference.
#
# ## References
#
# - Tool citation
# - Related publications
